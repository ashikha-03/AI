# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly as py
import plotly.graph_objs as go

from sklearn.cluster import KMeans

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('/content/Iris.csv')
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
dataset.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
X= dataset.iloc[:, [2,4]].values
X
# Out:
# array([[3.5, 0.2],
#        [3. , 0.2],
#        [3.2, 0.2],
#        [3.1, 0.2],
#        [3.6, 0.2],
#        [3.9, 0.4],
#        [3.4, 0.3],
#        [3.4, 0.2],
#        [2.9, 0.2],
#        [3.1, 0.1],
#        [3.7, 0.2],
#        [3.4, 0.2],
#        [3. , 0.1],
#        [3. , 0.1],
#        [4. , 0.2],
#        [4.4, 0.4],
#        [3.9, 0.4],
#        [3.5, 0.3],
#        [3.8, 0.3],
#        [3.8, 0.3],
#        [3.4, 0.2],
#        [3.7, 0.4],
#        [3.6, 0.2],
#        [3.3, 0.5],
#        [3.4, 0.2],
#        [3. , 0.2],
#        [3.4, 0.4],
#        [3.5, 0.2],
#        [3.4, 0.2],
#        [3.2, 0.2],
#        [3.1, 0.2],
#        [3.4, 0.4],
#        [4.1, 0.1],
#        [4.2, 0.2],
#        [3.1, 0.1],
#        [3.2, 0.2],
#        [3.5, 0.2],
#        [3.1, 0.1],
#        [3. , 0.2],
#        [3.4, 0.2],
#        [3.5, 0.3],
#        [2.3, 0.3],
#        [3.2, 0.2],
#        [3.5, 0.6],
#        [3.8, 0.4],
#        [3. , 0.3],
#        [3.8, 0.2],
#        [3.2, 0.2],
#        [3.7, 0.2],
#        [3.3, 0.2],
#        [3.2, 1.4],
#        [3.2, 1.5],
#        [3.1, 1.5],
#        [2.3, 1.3],
#        [2.8, 1.5],
#        [2.8, 1.3],
#        [3.3, 1.6],
#        [2.4, 1. ],
#        [2.9, 1.3],
#        [2.7, 1.4],
#        [2. , 1. ],
#        [3. , 1.5],
#        [2.2, 1. ],
#        [2.9, 1.4],
#        [2.9, 1.3],
#        [3.1, 1.4],
#        [3. , 1.5],
#        [2.7, 1. ],
#        [2.2, 1.5],
#        [2.5, 1.1],
#        [3.2, 1.8],
#        [2.8, 1.3],
#        [2.5, 1.5],
#        [2.8, 1.2],
#        [2.9, 1.3],
#        [3. , 1.4],
#        [2.8, 1.4],
#        [3. , 1.7],
#        [2.9, 1.5],
#        [2.6, 1. ],
#        [2.4, 1.1],
#        [2.4, 1. ],
#        [2.7, 1.2],
#        [2.7, 1.6],
#        [3. , 1.5],
#        [3.4, 1.6],
#        [3.1, 1.5],
#        [2.3, 1.3],
#        [3. , 1.3],
#        [2.5, 1.3],
#        [2.6, 1.2],
#        [3. , 1.4],
#        [2.6, 1.2],
#        [2.3, 1. ],
#        [2.7, 1.3],
#        [3. , 1.2],
#        [2.9, 1.3],
#        [2.9, 1.3],
#        [2.5, 1.1],
#        [2.8, 1.3],
#        [3.3, 2.5],
#        [2.7, 1.9],
#        [3. , 2.1],
#        [2.9, 1.8],
#        [3. , 2.2],
#        [3. , 2.1],
#        [2.5, 1.7],
#        [2.9, 1.8],
#        [2.5, 1.8],
#        [3.6, 2.5],
#        [3.2, 2. ],
#        [2.7, 1.9],
#        [3. , 2.1],
#        [2.5, 2. ],
#        [2.8, 2.4],
#        [3.2, 2.3],
#        [3. , 1.8],
#        [3.8, 2.2],
#        [2.6, 2.3],
#        [2.2, 1.5],
#        [3.2, 2.3],
#        [2.8, 2. ],
#        [2.8, 2. ],
#        [2.7, 1.8],
#        [3.3, 2.1],
#        [3.2, 1.8],
#        [2.8, 1.8],
#        [3. , 1.8],
#        [2.8, 2.1],
#        [3. , 1.6],
#        [2.8, 1.9],
#        [3.8, 2. ],
#        [2.8, 2.2],
#        [2.8, 1.5],
#        [2.6, 1.4],
#        [3. , 2.3],
#        [3.4, 2.4],
#        [3.1, 1.8],
#        [3. , 1.8],
#        [3.1, 2.1],
#        [3.1, 2.4],
#        [3.1, 2.3],
#        [2.7, 1.9],
#        [3.2, 2.3],
#        [3.3, 2.5],
#        [3. , 2.3],
#        [2.5, 1.9],
#        [3. , 2. ],
#        [3.4, 2.3],
#        [3. , 1.8]])

# %%
from sklearn.cluster import KMeans
wcss=[]

for i in range(1,11):
    kmeans = KMeans(n_clusters= i, init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11), wcss)
plt.title('Iris dataset')
plt.xlabel('Clusters')
plt.ylabel('Wcss')
plt.show()

# %%
kmeansmodel = KMeans(n_clusters= 3, init='k-means++', random_state=0)
y_kmeans= kmeansmodel.fit_predict(X)

# %%
plt.scatter(X_standardized[y_kmeans == 0, 0], X_standardized[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X_standardized[y_kmeans == 1, 0], X_standardized[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X_standardized[y_kmeans == 2, 0], X_standardized[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of Iris Species')
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e3b75e0d5a3e> in <cell line: 1>()
# ----> 1 plt.scatter(X_standardized[y_kmeans == 0, 0], X_standardized[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
#       2 plt.scatter(X_standardized[y_kmeans == 1, 0], X_standardized[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
#       3 plt.scatter(X_standardized[y_kmeans == 2, 0], X_standardized[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
#       4 plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
#       5 plt.title('Clusters of Iris Species')
#
# NameError: name 'X_standardized' is not defined
